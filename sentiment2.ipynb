# %%
# !pip install keras
# !pip install pandas
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Loading dataset from Google Drive**

# %%
#dataset path
import pandas as pd

data_path = '/content/drive/MyDrive/major project/emotion_dataset/emotions.csv'

df=pd.read_csv(data_path)
texts = []
emotions = []

for i in df.Text:
  i = str(i)
  texts.append(i)

for i in df.Emotion:
  i = str(i)
  emotions.append(i)

# %%
len(texts)
# Out:
# 87097

# %%
len(emotions)
# Out:
# 87097

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,4))
sns.countplot(x='Emotion', data=df);

# %% [markdown]
# **installing keras**

# %% [markdown]
# ** importing needed libraries**

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from keras.layers import Embedding

# %%
from sklearn.model_selection import train_test_split

# Assuming 'texts' and 'emotions' are your data
texts_train, texts_test, emotions_train, emotions_test = train_test_split(texts, emotions, test_size=0.2, random_state=42)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts_train)

sequences_train = tokenizer.texts_to_sequences(texts_train)
sequences_test = tokenizer.texts_to_sequences(texts_test)

max_length = max(len(seq) for seq in sequences_train + sequences_test)

padded_sequences_train = pad_sequences(sequences_train, maxlen=max_length)
padded_sequences_test = pad_sequences(sequences_test, maxlen=max_length)

# %%
# Assuming 'emotions_train' and 'emotions_test' are your labels
label_encoder = LabelEncoder()

# Fit the label encoder on the combined set of labels (train + test)
all_emotions = emotions_train + emotions_test
label_encoder.fit(all_emotions)

# Transform the string labels to numerical labels
numerical_labels_train = label_encoder.transform(emotions_train)
numerical_labels_test = label_encoder.transform(emotions_test)

# Perform one-hot encoding on the numerical labels
num_classes = len(label_encoder.classes_)
one_hot_labels_train = to_categorical(numerical_labels_train, num_classes=num_classes)
one_hot_labels_test = to_categorical(numerical_labels_test, num_classes=num_classes)

# %%
print(num_classes)


'''# Use the inverse_transform method to decode the numeric labels
decoded_labels = label_encoder.inverse_transform()
'''
# Now 'decoded_labels' contains the corresponding class names
print(label_encoder.classes_)
# Out:
# 6
# ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad']

# %% [markdown]
# # Defining LSTM **model**

# %% [markdown]
# Building  an LSTM model for sentiment analysis with a softmax activation function in the output layer.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding

embedding_dim = 100  # Adjust based on your chosen word embeddings
vocab_size = len(tokenizer.word_index) + 1

embedding_layer = Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=max_length)

model = Sequential()
model.add(embedding_layer)
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(num_classes, activation='softmax'))  # 5 is the number of unique emotion labels
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.

# %% [markdown]
# compiling the model

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 105, 100)          5068000
#
#  lstm (LSTM)                 (None, 100)               80400
#
#  dense (Dense)               (None, 6)                 606
#
# =================================================================
# Total params: 5149006 (19.64 MB)
# Trainable params: 5149006 (19.64 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file='model.png', show_shapes=True)

# %% [markdown]
# training the model with history

# %%
# Model Training with History
history = model.fit(
    padded_sequences_train, one_hot_labels_train,
    epochs=16, batch_size=32,
    validation_data=(padded_sequences_test, one_hot_labels_test)
)
# Out:
# Epoch 1/16
# 2178/2178 [==============================] - 788s 359ms/step - loss: 1.1410 - accuracy: 0.5552 - val_loss: 0.9352 - val_accuracy: 0.6449
# Epoch 2/16
# 2178/2178 [==============================] - 752s 345ms/step - loss: 0.7096 - accuracy: 0.7398 - val_loss: 0.9076 - val_accuracy: 0.6606
# Epoch 3/16
# 2178/2178 [==============================] - 748s 343ms/step - loss: 0.4756 - accuracy: 0.8329 - val_loss: 1.0075 - val_accuracy: 0.6619
# Epoch 4/16
# 2178/2178 [==============================] - 741s 340ms/step - loss: 0.3385 - accuracy: 0.8816 - val_loss: 1.0911 - val_accuracy: 0.6549
# Epoch 5/16
# 2178/2178 [==============================] - 754s 346ms/step - loss: 0.2597 - accuracy: 0.9079 - val_loss: 1.2032 - val_accuracy: 0.6575
# Epoch 6/16
#  665/2178 [========>.....................] - ETA: 8:21 - loss: 0.1810 - accuracy: 0.9365

# %% [markdown]
# # **Required graph for training and validation loss**

# %%
import matplotlib.pyplot as plt
##plot the scores from history
def plot_metrics(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric])
  plt.legend(['train','test'])
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.show()

##plot accuracy
plot_metrics(history, "accuracy")

##plot loss
plot_metrics(history, "loss")

# %% [markdown]
# confusion matrix

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report



# Model Prediction
predictions = model.predict(padded_sequences_test)
print(predictions)


predicted_label = [round(p[0]) for p in predictions]

# Assuming 'emotions_test' is your test labels
numerical_labels_test = label_encoder.transform(emotions_test)

print(predictions)
print(numerical_labels_test)

label=[]


#labeling the predicted encoded labels to original text

# Find the index of the maximum value
for i, array in enumerate(predictions):
    # Convert the array to a numpy array
    input_array = np.array(array)

    # Find the index of the maximum value
    predicted_label_index = np.argmax(input_array)

    # Assuming 'class_labels' is a list of your class labels
    class_labels = ['angry' 'disgust' 'fear' 'happy' 'neutral' 'sad']

    # Get the predicted label
    predicted_label = class_labels[predicted_label_index]
    label.append(predicted_label_index)
#print(f"Example {i+1} - Predicted Label Index: {predicted_label_index}, Predicted Label: {predicted_label}")
print(label)



# Confusion Matrix
conf_matrix = confusion_matrix(numerical_labels_test, label)

# Plotting Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

print(emotions_test)
print(numerical_labels_test)



# Basic Evaluation Metrics
accuracy = accuracy_score(numerical_labels_test, label)
precision = precision_score(numerical_labels_test, label, average='weighted')
recall = recall_score(numerical_labels_test, label, average='weighted')
f1 = f1_score(numerical_labels_test, label, average='weighted')

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")


# Classification Report
print(classification_report(numerical_labels_test, label, target_names=label_encoder.classes_))
# Out:
# 102/102 [==============================] - 2s 20ms/step
# [[3.9486090e-06 8.9045425e-06 6.8257905e-05 ... 5.7424045e-06
#   9.9989712e-01 5.2191726e-06]
#  [1.0532974e-06 2.9832399e-06 3.2839530e-06 ... 1.9181014e-06
#   9.9998975e-01 4.6388178e-07]
#  [8.6199543e-05 3.1079922e-04 4.8847600e-05 ... 9.4285876e-01
#   1.4486846e-04 2.5952922e-04]
#  ...
#  [1.9530711e-08 5.6293015e-08 5.9853267e-07 ... 1.1784667e-06
#   1.6086591e-06 3.9615923e-08]
#  [3.1614079e-05 9.8198903e-01 1.5111304e-03 ... 6.0496368e-03
#   7.8056930e-03 1.7651662e-03]
#  [2.1201267e-06 3.3101818e-04 2.9758324e-03 ... 5.7282396e-05
#   2.2231327e-06 9.9662280e-01]]
# [[3.9486090e-06 8.9045425e-06 6.8257905e-05 ... 5.7424045e-06
#   9.9989712e-01 5.2191726e-06]
#  [1.0532974e-06 2.9832399e-06 3.2839530e-06 ... 1.9181014e-06
#   9.9998975e-01 4.6388178e-07]
#  [8.6199543e-05 3.1079922e-04 4.8847600e-05 ... 9.4285876e-01
#   1.4486846e-04 2.5952922e-04]
#  ...
#  [1.9530711e-08 5.6293015e-08 5.9853267e-07 ... 1.1784667e-06
#   1.6086591e-06 3.9615923e-08]
#  [3.1614079e-05 9.8198903e-01 1.5111304e-03 ... 6.0496368e-03
#   7.8056930e-03 1.7651662e-03]
#  [2.1201267e-06 3.3101818e-04 2.9758324e-03 ... 5.7282396e-05
#   2.2231327e-06 9.9662280e-01]]
# [5 5 3 ... 3 1 6]
# [5, 5, 4, 3, 3, 5, 3, 3, 5, 1, 4, 3, 2, 4, 5, 5, 3, 0, 1, 5, 4, 5, 6, 4, 3, 1, 4, 5, 5, 1, 5, 2, 2, 4, 5, 4, 5, 2, 2, 6, 5, 4, 5, 3, 3, 3, 1, 3, 1, 3, 2, 4, 5, 1, 5, 4, 6, 3, 2, 3, 1, 5, 3, 3, 5, 3, 3, 3, 5, 2, 5, 3, 5, 5, 5, 3, 1, 5, 5, 3, 3, 2, 5, 3, 1, 3, 3, 5, 3, 3, 5, 3, 4, 3, 5, 1, 3, 1, 3, 3, 3, 3, 3, 5, 5, 5, 5, 0, 1, 3, 5, 3, 5, 2, 3, 5, 5, 0, 2, 3, 1, 3, 3, 2, 5, 5, 2, 2, 5, 1, 5, 1, 3, 1, 1, 3, 2, 5, 5, 3, 5, 1, 3, 3, 5, 5, 1, 6, 5, 4, 4, 2, 4, 5, 1, 2, 5, 2, 3, 3, 2, 5, 3, 3, 3, 3, 5, 3, 1, 3, 5, 1, 5, 2, 5, 1, 1, 5, 2, 3, 3, 1, 3, 5, 3, 1, 3, 2, 6, 1, 3, 3, 5, 3, 3, 2, 2, 5, 5, 3, 4, 3, 5, 6, 3, 3, 3, 5, 3, 3, 5, 5, 5, 3, 5, 3, 3, 1, 5, 1, 3, 3, 1, 5, 0, 2, 1, 3, 5, 3, 3, 3, 2, 3, 5, 3, 5, 2, 5, 5, 3, 3, 5, 5, 4, 1, 5, 5, 5, 5, 1, 3, 4, 1, 2, 3, 3, 5, 2, 3, 3, 4, 2, 3, 1, 4, 1, 5, 3, 5, 4, 5, 5, 4, 3, 3, 3, 2, 3, 5, 4, 3, 1, 2, 5, 3, 3, 3, 5, 5, 3, 2, 6, 5, 3, 5, 5, 5, 3, 1, 6, 5, 5, 6, 5, 6, 5, 2, 3, 5, 4, 2, 3, 5, 1, 5, 3, 3, 2, 5, 2, 5, 5, 3, 3, 5, 4, 3, 3, 3, 1, 3, 2, 1, 6, 1, 2, 5, 5, 3, 1, 2, 1, 3, 3, 0, 1, 3, 3, 1, 6, 2, 5, 3, 3, 1, 5, 5, 5, 3, 3, 2, 4, 3, 5, 5, 3, 3, 3, 1, 2, 3, 5, 4, 5, 3, 4, 3, 5, 3, 3, 1, 1, 3, 1, 4, 3, 2, 3, 3, 3, 0, 5, 5, 4, 3, 3, 2, 5, 1, 3, 3, 2, 2, 2, 5, 5, 4, 5, 5, 2, 3, 5, 5, 3, 4, 5, 1, 1, 5, 3, 5, 2, 1, 5, 5, 1, 5, 0, 3, 1, 3, 5, 6, 3, 5, 5, 3, 5, 5, 3, 3, 4, 1, 3, 1, 5, 1, 5, 1, 5, 5, 3, 5, 5, 1, 3, 5, 5, 5, 2, 5, 1, 1, 3, 1, 5, 3, 5, 5, 1, 4, 3, 5, 4, 4, 3, 5, 6, 3, 1, 3, 5, 1, 3, 1, 3, 3, 2, 6, 5, 2, 5, 3, 5, 5, 5, 3, 5, 1, 3, 5, 2, 2, 2, 2, 2, 5, 5, 3, 4, 5, 5, 1, 2, 5, 1, 4, 3, 1, 1, 3, 1, 3, 3, 2, 3, 3, 1, 1, 5, 5, 3, 6, 3, 3, 2, 4, 5, 5, 2, 5, 5, 5, 3, 5, 5, 5, 3, 3, 5, 5, 5, 5, 6, 5, 1, 5, 3, 3, 4, 3, 1, 5, 5, 3, 3, 3, 5, 4, 5, 2, 2, 5, 1, 1, 5, 2, 5, 4, 5, 5, 2, 2, 1, 5, 0, 6, 4, 3, 1, 3, 5, 5, 3, 4, 4, 1, 2, 1, 0, 5, 1, 5, 5, 3, 5, 5, 5, 5, 3, 3, 3, 6, 5, 5, 3, 3, 5, 2, 3, 5, 3, 1, 4, 4, 4, 5, 5, 3, 6, 3, 1, 5, 3, 5, 5, 3, 5, 3, 3, 5, 1, 6, 5, 2, 5, 2, 5, 2, 1, 5, 1, 5, 5, 3, 2, 3, 1, 3, 1, 1, 2, 3, 5, 5, 5, 5, 5, 2, 3, 2, 2, 3, 3, 4, 5, 4, 4, 5, 3, 5, 4, 3, 3, 5, 1, 4, 3, 5, 5, 5, 6, 3, 2, 5, 3, 3, 4, 5, 3, 3, 5, 6, 5, 5, 3, 5, 5, 6, 1, 2, 4, 2, 1, 4, 4, 3, 3, 2, 5, 5, 3, 3, 3, 1, 3, 4, 5, 5, 3, 3, 5, 3, 5, 1, 5, 3, 3, 3, 4, 5, 4, 5, 2, 1, 2, 3, 2, 3, 4, 1, 3, 2, 3, 2, 3, 3, 3, 3, 1, 1, 2, 1, 5, 3, 3, 3, 5, 4, 3, 3, 3, 4, 5, 5, 5, 2, 5, 5, 2, 1, 5, 1, 0, 5, 0, 1, 3, 3, 5, 3, 3, 3, 5, 3, 3, 2, 4, 5, 3, 3, 5, 3, 3, 5, 5, 5, 3, 3, 5, 5, 4, 3, 5, 5, 5, 4, 3, 4, 5, 3, 5, 2, 5, 3, 1, 5, 3, 3, 2, 3, 5, 2, 3, 5, 3, 2, 5, 4, 2, 1, 2, 4, 3, 1, 6, 5, 3, 5, 3, 3, 1, 5, 6, 5, 1, 3, 2, 1, 6, 3, 5, 5, 5, 3, 2, 5, 1, 5, 5, 5, 6, 5, 3, 5, 3, 3, 1, 3, 2, 3, 5, 3, 3, 3, 6, 4, 5, 3, 5, 5, 3, 2, 4, 5, 5, 3, 5, 1, 1, 3, 5, 6, 3, 3, 5, 5, 1, 0, 5, 5, 4, 1, 3, 2, 3, 3, 1, 5, 3, 3, 3, 1, 3, 3, 2, 5, 4, 5, 1, 5, 3, 3, 3, 5, 3, 3, 5, 5, 4, 3, 5, 2, 3, 4, 5, 3, 3, 5, 2, 3, 4, 3, 4, 4, 5, 3, 1, 4, 5, 3, 4, 3, 2, 3, 1, 5, 5, 1, 5, 3, 4, 5, 5, 5, 1, 3, 3, 6, 1, 5, 3, 4, 3, 3, 3, 2, 3, 2, 2, 3, 3, 1, 3, 3, 1, 1, 5, 2, 2, 5, 2, 3, 5, 3, 5, 2, 5, 3, 1, 5, 1, 4, 5, 5, 5, 5, 2, 5, 1, 3, 5, 2, 5, 2, 3, 1, 3, 3, 4, 3, 1, 4, 2, 3, 2, 4, 3, 5, 1, 3, 5, 3, 4, 1, 3, 1, 0, 5, 2, 5, 1, 5, 4, 5, 3, 3, 5, 4, 3, 3, 3, 5, 4, 5, 5, 6, 5, 3, 5, 2, 3, 2, 5, 3, 3, 1, 5, 4, 3, 5, 5, 3, 5, 5, 4, 3, 6, 6, 5, 1, 5, 5, 3, 5, 0, 1, 5, 6, 5, 3, 3, 2, 5, 5, 3, 3, 3, 3, 2, 1, 4, 3, 2, 5, 3, 3, 3, 6, 5, 3, 3, 1, 5, 3, 3, 5, 2, 6, 6, 5, 5, 1, 5, 3, 5, 4, 1, 3, 5, 1, 1, 2, 1, 2, 2, 2, 5, 5, 3, 3, 3, 1, 3, 2, 3, 5, 3, 5, 3, 2, 5, 3, 5, 3, 3, 2, 5, 5, 1, 3, 2, 3, 2, 4, 2, 2, 3, 5, 3, 1, 1, 5, 5, 1, 5, 5, 1, 5, 4, 3, 3, 3, 3, 6, 2, 3, 3, 1, 0, 3, 3, 5, 3, 3, 5, 1, 3, 3, 2, 5, 3, 5, 5, 3, 3, 3, 3, 5, 2, 6, 3, 5, 3, 3, 5, 5, 2, 5, 5, 4, 2, 3, 6, 3, 5, 3, 2, 4, 1, 3, 1, 3, 2, 1, 3, 5, 1, 3, 5, 3, 3, 5, 5, 3, 5, 2, 3, 1, 5, 2, 2, 3, 3, 3, 3, 3, 3, 2, 3, 0, 5, 2, 4, 5, 5, 3, 3, 1, 1, 1, 3, 3, 5, 5, 4, 3, 5, 1, 5, 3, 5, 5, 3, 2, 5, 5, 5, 5, 3, 5, 2, 6, 5, 4, 3, 4, 1, 5, 3, 1, 6, 5, 1, 5, 2, 5, 3, 5, 5, 3, 5, 1, 3, 6, 3, 5, 2, 5, 5, 3, 1,  ...
# ['sadness', 'sadness', 'joy', 'joy', 'joy', 'sadness', 'joy', 'joy', 'sadness', 'anger', 'love', 'joy', 'fear', 'love', 'sadness', 'sadness', 'joy', 'fear', 'anger', 'sadness', 'love', 'sadness', 'surprise', 'love', 'surprise', 'anger', 'love', 'sadness', 'sadness', 'anger', 'sadness', 'anger', 'fear', 'love', 'fear', 'love', 'sadness', 'fear', 'fear', 'surprise', 'sadness', 'love', 'sadness', 'joy', 'joy', 'joy', 'anger', 'joy', ' neutral', 'joy', 'fear', 'love', 'sadness', 'anger', 'sadness', 'love', 'fear', 'joy', 'fear', 'joy', 'anger', 'sadness', 'joy', 'joy', 'sadness', 'joy', 'joy', 'joy', 'sadness', 'fear', 'sadness', 'joy', 'sadness', 'sadness', 'sadness', 'joy', 'anger', 'sadness', 'sadness', 'joy', 'joy', 'sadness', 'sadness', 'joy', 'anger', 'joy', 'joy', 'sadness', 'joy', 'joy', 'sadness', 'joy', 'love', 'joy', 'sadness', 'anger', 'joy', 'anger', 'sadness', 'love', 'joy', 'joy', 'joy', 'sadness', 'sadness', 'sadness', 'sadness', ' neutral', 'anger', 'joy', 'love', 'joy', 'sadness', 'fear', 'joy', 'sadness', 'sadness', ' neutral', 'fear', 'joy', 'anger', 'joy', 'joy', 'joy', 'sadness', 'sadness', 'fear', 'fear', 'sadness', 'anger', 'sadness', 'anger', 'joy', 'anger', 'anger', 'joy', 'fear', 'sadness', 'sadness', 'joy', 'sadness', 'anger', 'joy', 'joy', 'sadness', 'sadness', 'anger', 'surprise', 'sadness', 'love', 'love', 'fear', 'love', 'sadness', 'fear', 'joy', 'sadness', 'fear', 'joy', 'love', 'fear', 'sadness', 'joy', 'joy', 'joy', 'joy', 'sadness', 'joy', 'anger', 'joy', 'sadness', 'anger', 'sadness', 'fear', 'sadness', 'anger', 'anger', 'sadness', 'fear', 'joy', 'joy', 'anger', 'joy', 'sadness', 'joy', 'anger', 'joy', 'fear', 'surprise', 'anger', 'joy', 'joy', 'sadness', 'joy', 'joy', 'fear', 'anger', 'sadness', 'sadness', 'joy', 'joy', 'joy', 'sadness', 'surprise', 'joy', 'joy', 'joy', 'sadness', 'joy', 'joy', 'sadness', 'sadness', 'sadness', 'love', 'sadness', 'joy', 'joy', 'anger', 'sadness', 'anger', 'joy', 'joy', 'anger', 'sadness', ' neutral', 'fear', 'anger', 'joy', 'sadness', 'joy', 'joy', 'joy', 'fear', 'joy', 'sadness', 'joy', 'sadness', 'fear', 'sadness', 'sadness', 'joy', 'joy', 'sadness', 'sadness', 'love', 'anger', 'sadness', 'sadness', 'sadness', 'sadness', 'anger', 'joy', 'love', 'anger', 'fear', 'joy', 'joy', 'sadness', 'fear', 'joy', 'joy', 'joy', 'fear', 'joy', 'joy', 'love', 'anger', 'sadness', 'joy', 'sadness', 'love', 'sadness', 'sadness', 'love', 'anger', 'joy', 'joy', 'surprise', 'joy', 'sadness', 'love', 'joy', 'anger', 'anger', 'sadness', 'love', 'joy', 'joy', 'sadness', 'sadness', 'love', 'fear', 'surprise', 'sadness', 'joy', 'sadness', 'sadness', 'sadness', 'joy', 'anger', 'surprise', 'sadness', 'sadness', 'surprise', 'sadness', 'fear', 'sadness', 'fear', 'joy', 'sadness', 'love', 'fear', 'joy', 'sadness', 'anger', 'sadness', 'joy', 'joy', 'fear', 'sadness', 'fear', 'sadness', 'sadness', 'joy', 'joy', 'sadness', 'love', 'joy', 'joy', 'joy', 'anger', 'joy', 'fear', 'anger', 'surprise', 'anger', 'love', 'sadness', 'sadness', 'love', 'anger', 'fear', 'anger', 'joy', 'joy', ' neutral', 'anger', 'joy', 'joy', 'anger', 'surprise', 'fear', 'sadness', 'joy', 'joy', 'anger', 'sadness', 'sadness', 'sadness', 'joy', 'joy', 'fear', 'love', 'joy', 'sadness', 'fear', 'joy', 'joy', 'joy', 'anger', 'fear', 'joy', 'sadness', 'love', 'sadness', 'joy', 'love', 'joy', 'sadness', 'joy', 'joy', 'sadness', 'anger', 'joy', 'anger', 'joy', 'joy', 'fear', 'joy', 'joy', 'joy', 'anger', 'sadness', 'sadness', 'love', 'joy', 'joy', 'fear', 'sadness', 'anger', 'joy', 'joy', 'sadness', 'fear', 'fear', 'sadness', 'sadness', 'love', 'sadness', 'sadness', 'fear', 'joy', 'sadness', 'sadness', 'joy', 'love', 'sadness', 'anger', 'anger', 'sadness', 'joy', 'sadness', 'fear', 'anger', 'sadness', 'sadness', 'anger', 'sadness', ' neutral', 'joy', 'anger', 'joy', 'sadness', 'surprise', 'joy', 'sadness', 'sadness', 'love', 'sadness', 'sadness', 'joy', 'joy', 'love', 'anger', 'joy', 'anger', 'sadness', 'anger', 'sadness', 'ang ...
# [5 5 3 ... 3 1 6]
# Accuracy: 0.9174
# Precision: 0.9170
# Recall: 0.9174
# F1-Score: 0.9169
#               precision    recall  f1-score   support
#
#      neutral       0.74      0.77      0.75        30
#        anger       0.91      0.91      0.91       423
#         fear       0.87      0.89      0.88       375
#          joy       0.92      0.95      0.94      1046
#         love       0.84      0.78      0.81       278
#      sadness       0.97      0.96      0.96       967
#     surprise       0.85      0.74      0.79       115
#
#     accuracy                           0.92      3234
#    macro avg       0.87      0.86      0.86      3234
# weighted avg       0.92      0.92      0.92      3234

# %% [markdown]
# Testing with one data

# %%
import pandas as pd
# Decode one-hot encoded labels back to original labels
decoded_predictions = label_encoder.inverse_transform(label)

# Display Predicted Labels and Original Text
results_df = pd.DataFrame({'Text': texts_test, 'True Label': emotions_test, 'Predicted Label': decoded_predictions})

# Display a subset of the results (adjust as needed)
subset_results = results_df.head(20)
print(subset_results)
# Out:
#                                                  Text True Label  \
# 0   ive heard stories about julie baileys treatmen...    sadness
# 1                     i feel all gloomy and i hate it    sadness
# 2   i feel like learning not to judge people is th...        joy
# 3   i feel sure that this will be a night to remember        joy
# 4                   i feel a bit optimistic some days        joy
# 5                             i feel extremely boring    sadness
# 6   i mane is feeling generous and releases his ne...        joy
# 7   i can eat soup drink tea and wear sweaters but...        joy
# 8                i can wear anything and not feel bad    sadness
# 9   i feel about puppy mills puppy mills are run b...      anger
# 10  i feel especially passionate about the friends...       love
# 11  i feel so friggin blessed with a wonderful car...        joy
# 12  i signed the petition and knowing that it will...       fear
# 13  im feeling romantic towards not another relati...       love
# 14  i feeling so miserable when actually my mum sh...    sadness
# 15       i feel shitty these few days because of work    sadness
# 16  i used to think that men needed their women to...        joy
# 17  during the last academic year ie just before t...       fear
# 18  i left the property feeling insulted and found...      anger
# 19  i see the areas where i should be doing better...    sadness
#
#    Predicted Label
# 0          sadness
# 1          sadness
# 2             love
# 3              joy
# 4              joy
# 5          sadness
# 6              joy
# 7              joy
# 8          sadness
# 9            anger
# 10            love
# 11             joy
# 12            fear
# 13            love
# 14         sadness
# 15         sadness
# 16             joy
# 17         neutral
# 18           anger
# 19         sadness

# %% [markdown]
# # **Saving the model**

# %%
from keras.models import save_model


# Specify the full path where you want to save the model
model_path = '/content/drive/MyDrive/training datasets/emotion_model.h5'

# Save the model to the specified path
model.save(model_path)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
